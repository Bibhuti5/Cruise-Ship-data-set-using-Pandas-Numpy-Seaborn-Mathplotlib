# %% [markdown]
# # Cruise Ship data set using Pandas,Numpy,Seaborn,Mathplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # loading dataset from cloud

# %%
url = "https://raw.githubusercontent.com/bot13956/ML_Model_for_Predicting_Ships_Crew_Size/master/cruise_ship_info.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#      Ship_name Cruise_line  Age  Tonnage  passengers  length  cabins  \
# 0      Journey     Azamara    6   30.277        6.94    5.94    3.55
# 1        Quest     Azamara    6   30.277        6.94    5.94    3.55
# 2  Celebration    Carnival   26   47.262       14.86    7.22    7.43
# 3     Conquest    Carnival   11  110.000       29.74    9.53   14.88
# 4      Destiny    Carnival   17  101.353       26.42    8.92   13.21
#
#    passenger_density   crew
# 0              42.64   3.55
# 1              42.64   3.55
# 2              31.80   6.70
# 3              36.99  19.10
# 4              38.36  10.00

# %%
df.columns
# Out:
# Index(['Ship_name', 'Cruise_line', 'Age', 'Tonnage', 'passengers', 'length',
#        'cabins', 'passenger_density', 'crew'],
#       dtype='object')

# %%
df.tail()
# Out:
#     Ship_name Cruise_line  Age  Tonnage  passengers  length  cabins  \
# 153    Taurus        Star   22    3.341        0.66    2.79    0.33
# 154     Virgo        Star   14   76.800       19.60    8.79    9.67
# 155    Spirit    Windstar   25    5.350        1.58    4.40    0.74
# 156      Star    Windstar   27    5.350        1.67    4.40    0.74
# 157      Surf    Windstar   23   14.745        3.08    6.17    1.56
#
#      passenger_density   crew
# 153              50.62   0.59
# 154              39.18  12.00
# 155              33.86   0.88
# 156              32.04   0.88
# 157              47.87   1.80

# %%
df.describe()
# Out:
#               Age     Tonnage  passengers      length      cabins  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean    15.689873   71.284671   18.457405    8.130633    8.830000
# std      7.615691   37.229540    9.677095    1.793474    4.471417
# min      4.000000    2.329000    0.660000    2.790000    0.330000
# 25%     10.000000   46.013000   12.535000    7.100000    6.132500
# 50%     14.000000   71.899000   19.500000    8.555000    9.570000
# 75%     20.000000   90.772500   24.845000    9.510000   10.885000
# max     48.000000  220.000000   54.000000   11.820000   27.000000
#
#        passenger_density        crew
# count         158.000000  158.000000
# mean           39.900949    7.794177
# std             8.639217    3.503487
# min            17.700000    0.590000
# 25%            34.570000    5.480000
# 50%            39.085000    8.150000
# 75%            44.185000    9.990000
# max            71.430000   21.000000

# %%
df.isnull().sum()
# Out:
# Ship_name            0
# Cruise_line          0
# Age                  0
# Tonnage              0
# passengers           0
# length               0
# cabins               0
# passenger_density    0
# crew                 0
# dtype: int64

# %%
df.isnull()
# Out:
#      Ship_name  Cruise_line    Age  Tonnage  passengers  length  cabins  \
# 0        False        False  False    False       False   False   False
# 1        False        False  False    False       False   False   False
# 2        False        False  False    False       False   False   False
# 3        False        False  False    False       False   False   False
# 4        False        False  False    False       False   False   False
# ..         ...          ...    ...      ...         ...     ...     ...
# 153      False        False  False    False       False   False   False
# 154      False        False  False    False       False   False   False
# 155      False        False  False    False       False   False   False
# 156      False        False  False    False       False   False   False
# 157      False        False  False    False       False   False   False
#
#      passenger_density   crew
# 0                False  False
# 1                False  False
# ...

# %% [markdown]
# # Relating the variables with scatterplots

# %%
sns.relplot(x="Cruise_line",y="Tonnage",data=df)

# %%
sns.relplot(x="Age", y="crew", data=df)

# %%
sns.relplot(x="length", y="cabins", data=df)

# %%
sns.pairplot(df)

# %%
sns.relplot(x='length', y='cabins', kind='line', data=df)

# %%
df.columns
# Out:
# Index(['Ship_name', 'Cruise_line', 'Age', 'Tonnage', 'passengers', 'length',
#        'cabins', 'passenger_density', 'crew'],
#       dtype='object')

# %%
sns.catplot(x='Age',y='crew',data=df)

# %%
sns.relplot(x="length", y="cabins",hue='Age' data=df)
# Out:
#   File "<ipython-input-39-72874cdf7873>", line 1
#     sns.relplot(x="length", y="cabins",hue='Age' data=df)
#                                                     ^
# SyntaxError: invalid syntax
